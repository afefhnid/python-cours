# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('data/house_pricing.csv')
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
dataNew = data.drop(list(data)[0:14], axis=1)

# %%
dataNew.corr()
# Out:
#                GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# GrLivArea       1.000000      0.034836     -0.018918  0.630012  0.415772
# BsmtFullBath    0.034836      1.000000     -0.147871 -0.064512 -0.030905
# BsmtHalfBath   -0.018918     -0.147871      1.000000 -0.054536 -0.012340
# FullBath        0.630012     -0.064512     -0.054536  1.000000  0.136381
# HalfBath        0.415772     -0.030905     -0.012340  0.136381  1.000000
# BedroomAbvGr    0.521270     -0.150673      0.046519  0.363252  0.226651
# KitchenAbvGr    0.100063     -0.041503     -0.037944  0.133115 -0.068263
# TotRmsAbvGrd    0.825489     -0.053275     -0.023836  0.554784  0.343415
# Fireplaces      0.461679      0.137928      0.028976  0.243671  0.203649
# GarageYrBlt     0.231197      0.124553     -0.077464  0.484557  0.196785
# GarageCars      0.467247      0.131881     -0.020891  0.469672  0.219178
# GarageArea      0.468997      0.179189     -0.024536  0.405656  0.163549
# ...

# %%
sns.heatmap(dataNew.corr())

# %%
plt.show()
